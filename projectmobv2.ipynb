# %%
# First we import libararies
import os
import cv2
import random
import numpy as np
from tqdm import tqdm
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.metrics import roc_curve, auc
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.applications.resnet50 import ResNet50, preprocess_input
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras import layers, models, optimizers, regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
# Out:
# 2025-12-17 21:08:38.032422: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766005718.213961      38 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766005718.266589      38 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
base_path = "/kaggle/input/brisc2025/brisc2025/classification_task/train"
base_path2 = "/kaggle/input/brisc2025/brisc2025/classification_task/test"

# %%
classes = os.listdir(base_path)
print("Classes:", classes)
# Out:
# Classes: ['pituitary', 'no_tumor', 'meningioma', 'glioma']

# %%
#distrubution of data
counts = {cls: len(os.listdir(os.path.join(base_path, cls))) for cls in classes}
print("Number of images per class:", counts)
plt.figure(figsize=(10,5))
plt.bar(counts.keys(), counts.values(), color=['skyblue', 'lightgreen', 'salmon', 'orange'])
plt.title("Number of Images per Class")
plt.xlabel("Class")
plt.ylabel("Number of Images")
plt.show()
# Out:
# Number of images per class: {'pituitary': 300, 'no_tumor': 140, 'meningioma': 306, 'glioma': 254}

# %%
#random sample show
random.seed(24)
plt.figure(figsize=(12, 8))
for i, cls in enumerate(classes):
    img_name = random.choice(os.listdir(os.path.join(base_path, cls)))
    img_path = os.path.join(base_path, cls, img_name)
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    plt.subplot(2, 2, i+1)
    plt.imshow(img)
    plt.title(cls)
    plt.axis("off")
plt.show()

# %%
#dimensions analysis
shapes = []
for cls in classes:
    for img_name in os.listdir(os.path.join(base_path, cls))[:100]:
        img_path = os.path.join(base_path, cls, img_name)
        img = cv2.imread(img_path)
        if img is not None:
            shapes.append(img.shape[:2])

shapes = np.array(shapes)
print("Average image size (H, W):", shapes.mean(axis=0))
print("Most common image sizes:", Counter([tuple(s) for s in shapes]).most_common(5))
# Out:
# Average image size (H, W): [482.5475 468.4025]
# Most common image sizes: [((512, 512), 316), ((369, 216), 32), ((369, 369), 29), ((256, 256), 3), ((369, 210), 2)]

# %%
# Pixel intensity distribution for all classes
random.seed(24)
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
axes = axes.ravel()

colors = ['blue', 'green', 'red', 'orange']

for i, cls in enumerate(classes):
    sample_img_name = random.choice(os.listdir(os.path.join(base_path, cls)))
    sample_img_path = os.path.join(base_path, cls, sample_img_name)

    img = cv2.imread(sample_img_path)
    img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    axes[i].hist(img_gray.ravel(), bins=50, color=colors[i], alpha=0.7)
    axes[i].set_title(f"Pixel Intensity Distribution ({cls})")
    axes[i].set_xlabel("Pixel value")
    axes[i].set_ylabel("Frequency")
    axes[i].grid(alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Detailed statistics for each class
pixel_stats = {}

for cls in classes:
    class_path = os.path.join(base_path, cls)
    all_pixels = []

    for img_name in os.listdir(class_path)[:20]:
        img_path = os.path.join(class_path, img_name)
        img = cv2.imread(img_path)

        if img is not None:
            img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            all_pixels.extend(img_gray.ravel())

    if all_pixels:
        pixel_stats[cls] = {
            'mean': np.mean(all_pixels),
            'std': np.std(all_pixels),
            'min': np.min(all_pixels),
            'max': np.max(all_pixels),
            'median': np.median(all_pixels)
        }

print("Pixel Intensity Statistics per Class:")
print("="*50)  # Separator line
for cls, stats in pixel_stats.items():
    print(f"{cls:12} | Mean: {stats['mean']:6.2f} | Std: {stats['std']:6.2f} | "
          f"Range: [{stats['min']:3d}, {stats['max']:3d}]")
# Out:
# Pixel Intensity Statistics per Class:
# ==================================================
# pituitary    | Mean:  48.48 | Std:  41.92 | Range: [  0, 255]
# no_tumor     | Mean:  51.64 | Std:  56.02 | Range: [  0, 255]
# meningioma   | Mean:  38.79 | Std:  45.50 | Range: [  0, 255]
# glioma       | Mean:  36.46 | Std:  40.67 | Range: [  0, 255]

# %%
#check on null images
bad_images = []
for cls in classes:
    for img_name in os.listdir(os.path.join(base_path, cls)):
        img_path = os.path.join(base_path, cls, img_name)
        img = cv2.imread(img_path)
        if img is None or img.size == 0:
            bad_images.append(img_path)

print("Number of bad images:", len(bad_images))
if bad_images:
    print("Examples of bad images:", bad_images[:5])
# Out:
# Number of bad images: 0

# %%
#function to resize images to 256x256
def resize_image(img, target_size=(256, 256)):
    return cv2.resize(img, target_size)

# %%
#see what happens after resize
random.seed(24)
plt.figure(figsize=(12, 8))
for i, cls in enumerate(classes):
    img_name = random.choice(os.listdir(os.path.join(base_path, cls)))
    img_path = os.path.join(base_path, cls, img_name)
    img = cv2.imread(img_path)
    img_original = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_resized = resize_image(img, target_size=(256, 256))


    plt.subplot(len(classes), 2, 2*i + 1)
    plt.imshow(img_original)
    plt.title(f"{cls}  Original")
    plt.axis("off")


    plt.subplot(len(classes), 2, 2*i + 2)
    plt.imshow(img_resized)
    plt.title(f"{cls}  Resized")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
#function to normalize data using min max
def normalize_image(img):
    return img.astype("float32") / 255.0

# %%
#function to applay histogram equalization using CLAHE
def enhance_contrast(img):
    if len(img.shape) == 3:
        img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
    else:
        img_gray = img

    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    img_enhanced = clahe.apply(img_gray)
    return cv2.cvtColor(img_enhanced, cv2.COLOR_GRAY2RGB)

# %%
#see what happens after histogram equalization
random.seed(24)
plt.figure(figsize=(12, 8))

for i, cls in enumerate(classes):
    img_name = random.choice(os.listdir(os.path.join(base_path, cls)))
    img_path = os.path.join(base_path, cls, img_name)

    img = cv2.imread(img_path)
    img_original = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img_processed = enhance_contrast(img_original)

    plt.subplot(len(classes), 2, 2*i + 1)
    plt.imshow(img_original)
    plt.title(f"{cls}  Original")
    plt.axis("off")

    plt.subplot(len(classes), 2, 2*i + 2)
    plt.imshow(img_processed)
    plt.title(f"{cls} Enhanced")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
#define the augmentation we want
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True
)
#funtion on one image
def augment_image(img):
    img = np.expand_dims(img, axis=0)
    it = datagen.flow(img, batch_size=1)
    return next(it)[0].astype("float32")

# %%
#the balancing function using augmentation if needed
def balance_with_augmentation(X, y, class_names, target_size=(256,256)):
    counts = Counter(y)
    max_count = max(counts.values())

    X_balanced, y_balanced = list(X), list(y)

    for class_idx, class_name in enumerate(class_names):
        deficit = max_count - counts[class_idx]
        if deficit > 0:
            print(f"Augmenting class {class_name} with {deficit} new samples...")
            class_imgs = [img for img, label in zip(X, y) if label == class_idx]

            for i in range(deficit):
                img = random.choice(class_imgs)
                aug_img = augment_image(img)
                X_balanced.append(aug_img)
                y_balanced.append(class_idx)

    return np.array(X_balanced), np.array(y_balanced)

# %%
#function of preprocceing pipline which is resize,denoise,enhance,normalize
def preprocess_pipeline(img, target_size=(256, 256), augment=False):
    img = resize_image(img, target_size)
    img = enhance_contrast(img)
    img = normalize_image(img)

    if augment:
        img = augment_image(img)

    return img

# %%
#function to load and applay pipeline
def load_and_preprocess_dataset(base_path, target_size=(256,256), augment=False, save_to=None):
    X, y = [], []
    class_names = os.listdir(base_path)

    for class_idx, class_name in enumerate(class_names):
        class_dir = os.path.join(base_path, class_name)
        if not os.path.isdir(class_dir):
            continue

        print(f"Processing class: {class_name}")
        for file in tqdm(os.listdir(class_dir)):
            file_path = os.path.join(class_dir, file)
            img = cv2.imread(file_path)
            if img is None:
                continue

            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = preprocess_pipeline(img, target_size=target_size, augment=augment)

            X.append(img)
            y.append(class_idx)

            if save_to:
                save_class_dir = os.path.join(save_to, class_name)
                os.makedirs(save_class_dir, exist_ok=True)
                save_path = os.path.join(save_class_dir, file)
                cv2.imwrite(save_path, cv2.cvtColor((img*255).astype(np.uint8), cv2.COLOR_RGB2BGR))

    return np.array(X), np.array(y), class_names

# %%
#applay the functions
X, y, class_names = load_and_preprocess_dataset(
    base_path=base_path,
    target_size=(256,256),
    augment=False,
    save_to="./processed"
)
X2, y2, class_names2 = load_and_preprocess_dataset(
    base_path=base_path2,
    target_size=(256,256),
    augment=False,
    save_to="./processed2"
)

print("Dataset shape:", X.shape, y.shape)
print("Classes:", class_names)
print("Dataset shape:", X2.shape, y2.shape)
print("Classes:", class_names2)
# Out:
# Processing class: pituitary
# 100%|██████████| 1457/1457 [00:14<00:00, 98.11it/s]
# Processing class: no_tumor
# 100%|██████████| 1067/1067 [00:09<00:00, 108.64it/s]
# Processing class: meningioma
# 100%|██████████| 1329/1329 [00:12<00:00, 104.49it/s]
# Processing class: glioma
# 100%|██████████| 1147/1147 [00:10<00:00, 109.49it/s]
# Processing class: pituitary
# 100%|██████████| 300/300 [00:03<00:00, 99.69it/s]
# Processing class: no_tumor
# 100%|██████████| 140/140 [00:01<00:00, 116.06it/s]
# Processing class: meningioma
# 100%|██████████| 306/306 [00:03<00:00, 101.13it/s]
# Processing class: glioma
# 100%|██████████| 254/254 [00:02<00:00, 95.81it/s]
# Dataset shape: (5000, 256, 256, 3) (5000,)
# Classes: ['pituitary', 'no_tumor', 'meningioma', 'glioma']
# Dataset shape: (1000, 256, 256, 3) (1000,)
# Classes: ['pituitary', 'no_tumor', 'meningioma', 'glioma']

# %%
#  Balance Dataset using Augmentation
X, y = balance_with_augmentation(X, y, class_names)
print("Balanced dataset shape:", X.shape, y.shape)

from collections import Counter
print("Class distribution after balancing:", Counter(y))
# Out:
# Augmenting class no_tumor with 390 new samples...
# Augmenting class meningioma with 128 new samples...
# Augmenting class glioma with 310 new samples...
# Balanced dataset shape: (5828, 256, 256, 3) (5828,)
# Class distribution after balancing: Counter({0: 1457, 1: 1457, 2: 1457, 3: 1457})

# %%
# One-hot encode labels
y = to_categorical(y, num_classes=len(class_names))
y2 = to_categorical(y2, num_classes=len(class_names2))

# %%
X_train = np.array([cv2.resize(img, (224,224)) for img in X])
X_val  = np.array([cv2.resize(img, (224,224)) for img in X2])

# %%
def build_model(num_classes, dropout_rate=0.4, l2_reg=1e-4, lr=1e-3):
    base_model = MobileNetV2(weights="imagenet", include_top=False, input_shape=(224,224,3))
    base_model.trainable = False

    inputs = layers.Input(shape=(224,224,3))
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(dropout_rate)(x)
    outputs = layers.Dense(num_classes, activation="softmax",
                           kernel_regularizer=regularizers.l2(l2_reg))(x)

    model = models.Model(inputs, outputs)
    model.compile(
        optimizer=optimizers.Adam(learning_rate=lr),
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )
    return model, base_model

# %%
mc = ModelCheckpoint(
    "best_model.h5",
    monitor="val_loss",
    save_best_only=True,
    save_weights_only=False,
    verbose=1
)
es = EarlyStopping(monitor="val_loss", patience=5, restore_best_weights=True)

model, base_model = build_model(num_classes=len(class_names))
history = model.fit(
    X_train, y,
    validation_data=(X_val, y2),
    epochs=10,
    batch_size=32,
    callbacks=[es, mc],
    verbose=1
)
# Out:
# Epoch 1/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5895 - loss: 0.9907
# Epoch 1: val_loss improved from inf to 0.52791, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 23s 80ms/step - accuracy: 0.5902 - loss: 0.9892 - val_accuracy: 0.8070 - val_loss: 0.5279
# Epoch 2/10
# 182/183 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8428 - loss: 0.4192
# Epoch 2: val_loss improved from 0.52791 to 0.48437, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8429 - loss: 0.4190 - val_accuracy: 0.8250 - val_loss: 0.4844
# Epoch 3/10
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8644 - loss: 0.3578
# Epoch 3: val_loss improved from 0.48437 to 0.40155, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8645 - loss: 0.3576 - val_accuracy: 0.8470 - val_loss: 0.4015
# Epoch 4/10
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8882 - loss: 0.3022
# Epoch 4: val_loss improved from 0.40155 to 0.37478, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8881 - loss: 0.3024 - val_accuracy: 0.8510 - val_loss: 0.3748
# Epoch 5/10
# 182/183 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8887 - loss: 0.2957
# Epoch 5: val_loss did not improve from 0.37478
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8888 - loss: 0.2956 - val_accuracy: 0.8560 - val_loss: 0.3794
# Epoch 6/10
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8901 - loss: 0.2830
# Epoch 6: val_loss improved from 0.37478 to 0.33219, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 29ms/step - accuracy: 0.8902 - loss: 0.2830 - val_accuracy: 0.8730 - val_loss: 0.3322
# Epoch 7/10
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8948 - loss: 0.2738
# Epoch 7: val_loss did not improve from 0.33219
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8949 - loss: 0.2738 - val_accuracy: 0.8550 - val_loss: 0.3777
# Epoch 8/10
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9003 - loss: 0.2498
# Epoch 8: val_loss did not improve from 0.33219
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9003 - loss: 0.2499 - val_accuracy: 0.8700 - val_loss: 0.3418
# Epoch 9/10
# 182/183 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8973 - loss: 0.2744
# Epoch 9: val_loss did not improve from 0.33219
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 28ms/step - accuracy: 0.8973 - loss: 0.2744 - val_accuracy: 0.8560 - val_loss: 0.3513
# Epoch 10/10
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9120 - loss: 0.2436
# Epoch 10: val_loss did not improve from 0.33219
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.9120 - loss: 0.2436 - val_accuracy: 0.8740 - val_loss: 0.3371

# %%
base_model.trainable = True
for layer in base_model.layers[:-50]:
    layer.trainable = False

model.compile(
    optimizer=optimizers.Adam(learning_rate=1e-5),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

history_ft = model.fit(
    X_train, y,
    validation_data=(X_val, y2),
    epochs=15,
    batch_size=32,
    callbacks=[es, mc],
    verbose=1
)
# Out:
# Epoch 1/15
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7713 - loss: 0.6325
# Epoch 1: val_loss did not improve from 0.33219
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 42s 111ms/step - accuracy: 0.7716 - loss: 0.6318 - val_accuracy: 0.8510 - val_loss: 0.4428
# Epoch 2/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.8748 - loss: 0.3317
# Epoch 2: val_loss did not improve from 0.33219
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.8750 - loss: 0.3314 - val_accuracy: 0.8500 - val_loss: 0.4731
# Epoch 3/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9004 - loss: 0.2642
# Epoch 3: val_loss did not improve from 0.33219
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 37ms/step - accuracy: 0.9004 - loss: 0.2640 - val_accuracy: 0.8610 - val_loss: 0.4616
# Epoch 4/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9214 - loss: 0.2064
# Epoch 4: val_loss did not improve from 0.33219
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.9215 - loss: 0.2061 - val_accuracy: 0.8710 - val_loss: 0.4156
# Epoch 5/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9439 - loss: 0.1531
# Epoch 5: val_loss did not improve from 0.33219
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - accuracy: 0.9439 - loss: 0.1531 - val_accuracy: 0.8760 - val_loss: 0.3711
# Epoch 6/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9540 - loss: 0.1328
# Epoch 6: val_loss improved from 0.33219 to 0.32215, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.9540 - loss: 0.1328 - val_accuracy: 0.8860 - val_loss: 0.3221
# Epoch 7/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9650 - loss: 0.0977
# Epoch 7: val_loss improved from 0.32215 to 0.28273, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.9649 - loss: 0.0978 - val_accuracy: 0.8970 - val_loss: 0.2827
# Epoch 8/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9691 - loss: 0.0866
# Epoch 8: val_loss improved from 0.28273 to 0.23658, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.9692 - loss: 0.0866 - val_accuracy: 0.9030 - val_loss: 0.2366
# Epoch 9/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9718 - loss: 0.0775
# Epoch 9: val_loss improved from 0.23658 to 0.20616, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.9718 - loss: 0.0775 - val_accuracy: 0.9170 - val_loss: 0.2062
# Epoch 10/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9778 - loss: 0.0652
# Epoch 10: val_loss improved from 0.20616 to 0.17993, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.9779 - loss: 0.0651 - val_accuracy: 0.9310 - val_loss: 0.1799
# Epoch 11/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9849 - loss: 0.0537
# Epoch 11: val_loss improved from 0.17993 to 0.17696, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.9848 - loss: 0.0538 - val_accuracy: 0.9370 - val_loss: 0.1770
# Epoch 12/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9869 - loss: 0.0480
# Epoch 12: val_loss improved from 0.17696 to 0.14585, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.9868 - loss: 0.0480 - val_accuracy: 0.9540 - val_loss: 0.1458
# Epoch 13/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9866 - loss: 0.0430
# Epoch 13: val_loss improved from 0.14585 to 0.13578, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.9866 - loss: 0.0430 - val_accuracy: 0.9550 - val_loss: 0.1358
# Epoch 14/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9914 - loss: 0.0361
# Epoch 14: val_loss improved from 0.13578 to 0.13092, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.9914 - loss: 0.0361 - val_accuracy: 0.9570 - val_loss: 0.1309
# Epoch 15/15
# 181/183 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9902 - loss: 0.0307
# Epoch 15: val_loss improved from 0.13092 to 0.12261, saving model to best_model.h5
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - accuracy: 0.9903 - loss: 0.0307 - val_accuracy: 0.9570 - val_loss: 0.1226

# %%
from tensorflow.keras.models import load_model
model = load_model("best_model.h5")

# %%
model.summary()
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 7, 7, 1280)     │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_2      │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 4)              │         5,124 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,263,110 (8.63 MB)
#  Trainable params: 1,860,228 (7.10 MB)
#  Non-trainable params: 402,880 (1.54 MB)
#  Optimizer params: 2 (12.00 B)

# %%
# Final evaluation for testing
val_loss, val_acc = model.evaluate(X_val, y2, verbose=1)
print(f" Validation Loss: {val_loss:.4f}")
print(f" Validation Accuracy: {val_acc:.4f}")

# Classification report & Confusion Matrix
y_pred = model.predict(X_val)
y_true = np.argmax(y2, axis=1)
y_pred = np.argmax(y_pred, axis=1)

print("\n Classification Report:\n")
print(classification_report(y_true, y_pred, target_names=class_names2))

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names2, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix")
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.9818 - loss: 0.0552
#  Validation Loss: 0.1226
#  Validation Accuracy: 0.9570
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 7s 118ms/step
#
#  Classification Report:
#
#               precision    recall  f1-score   support
#
#    pituitary       0.96      0.99      0.98       300
#     no_tumor       0.97      1.00      0.98       140
#   meningioma       0.92      0.95      0.94       306
#       glioma       0.99      0.90      0.94       254
#
#     accuracy                           0.96      1000
#    macro avg       0.96      0.96      0.96      1000
# weighted avg       0.96      0.96      0.96      1000

# %%
# Plot training & validation accuracy/loss
plt.figure(figsize=(12,5))

# Accuracy
plt.subplot(1,2,1)
plt.plot(history_ft.history['accuracy'], label='Train Accuracy')
plt.plot(history_ft.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss
plt.subplot(1,2,2)
plt.plot(history_ft.history['loss'], label='Train Loss')
plt.plot(history_ft.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
y_true_onehot = y2
y_pred_prob = model.predict(X_val)
n_classes = 4

fpr = {}
tpr = {}
roc_auc = {}

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_onehot[:, i], y_pred_prob[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(8, 6))

for i in range(n_classes):
    plt.plot(
        fpr[i],
        tpr[i],
        label=f'{class_names2[i]} (AUC = {roc_auc[i]:.2f})'
    )

plt.plot([0, 1], [0, 1], 'k--', label='Random')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve (Validation Set)')
plt.legend()
plt.grid(True)
plt.show()

print("AUC for each class:\n")
for i in range(n_classes):
    print(f"{class_names2[i]}: {roc_auc[i]:.4f}")
macro_auc = np.mean(list(roc_auc.values()))
print(f"Macro Average AUC: {macro_auc:.4f}")
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# AUC for each class:
#
# pituitary: 0.9995
# no_tumor: 0.9999
# meningioma: 0.9921
# glioma: 0.9955
# Macro Average AUC: 0.9968

# %%
# Sample predictions visualization
plt.figure(figsize=(12, 8))
for i, idx in enumerate(np.random.choice(len(X_val), 8, replace=False)):
    plt.subplot(2, 4, i+1)
    plt.imshow((X_val[idx] * 255).astype("uint8"))
    true_label = class_names[y_true[idx]]
    pred_label = class_names[y_pred[idx]]
    color = "green" if true_label == pred_label else "red"
    plt.title(f"True: {true_label}\nPred: {pred_label}", color=color, fontsize=9)
    plt.axis("off")

plt.tight_layout()
plt.show()
